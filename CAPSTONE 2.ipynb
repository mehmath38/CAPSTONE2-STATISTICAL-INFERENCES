# %% [markdown]
# ### 2ND CAPSTONE PROJECT:
#     INCOME LEVEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('adult.csv')
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
data['marital.status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
data['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data['relationship'].value_counts()
# Out:
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
data['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
data['native.country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
data['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ##

# %%
white = data[data['race']=='White']
white = white.groupby(['education','workclass']).size()
white.plot(kind='bar',figsize=(40,14))

# %%
male = data[data['sex']=='Male']
male.head()
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 6    38           Private  150601          10th              6      Separated
# 9    41           Private   70037  Some-college             10  Never-married
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
# 13   32           Private  136204       Masters             14      Separated
# 14   51                 ?  172175     Doctorate             16  Never-married
#
#          occupation   relationship   race   sex  capital.gain  capital.loss  \
# 6      Adm-clerical      Unmarried  White  Male             0          3770
# 9      Craft-repair      Unmarried  White  Male             0          3004
# 11   Prof-specialty  Not-in-family  White  Male             0          2824
# 13  Exec-managerial  Not-in-family  White  Male             0          2824
# 14                ?  Not-in-family  White  Male             0          2824
#
# ...

# %%
data.groupby(['sex','income']).size()
# Out:
# sex     income
# Female  <=50K      9592
#         >50K       1179
# Male    <=50K     15128
#         >50K       6662
# dtype: int64

# %%
data.groupby(['income','sex']).size().plot(kind='bar')

# %%
data.groupby(['income','marital.status']).size()
# Out:
# income  marital.status
# <=50K   Divorced                  3980
#         Married-AF-spouse           13
#         Married-civ-spouse        8284
#         Married-spouse-absent      384
#         Never-married            10192
#         Separated                  959
#         Widowed                    908
# >50K    Divorced                   463
#         Married-AF-spouse           10
#         Married-civ-spouse        6692
#         Married-spouse-absent       34
#         Never-married              491
#         Separated                   66
#         Widowed                     85
# dtype: int64

# %%
d = data
d = d[(d['native.country']=='United-States')|(d['native.country']=='Mexico')]
d.groupby(['native.country','education']).size()
# Out:
# native.country  education
# Mexico          10th              25
#                 11th              26
#                 12th              16
#                 1st-4th           64
#                 5th-6th          148
#                 7th-8th           53
#                 9th               53
#                 Assoc-acdm         3
#                 Assoc-voc          9
#                 Bachelors         29
#                 Doctorate          1
#                 HS-grad          129
#                 Masters            5
#                 Preschool         17
#                 Prof-school        2
#                 Some-college      63
# United-States   10th             848
#                 11th            1067
#                 12th             365
#                 1st-4th           46
#                 5th-6th           97
#                 7th-8th          499
#                 9th              395
#                 Assoc-acdm       982
# ...

# %%
d = data
d = d[(d['native.country']=='United-States')|(d['native.country']=='Mexico')]
e = d.groupby(['native.country','education']).size()

# %%
e.unstack()
# Out:
# education       10th  11th  12th  1st-4th  5th-6th  7th-8th  9th  Assoc-acdm  \
# native.country
# Mexico            25    26    16       64      148       53   53           3
# United-States    848  1067   365       46       97      499  395         982
#
# education       Assoc-voc  Bachelors  Doctorate  HS-grad  Masters  Preschool  \
# native.country
# Mexico                  9         29          1      129        5         17
# United-States        1289       4766        328     9702     1527         17
#
# education       Prof-school  Some-college
# native.country
# Mexico                    2            63
# United-States           502          6740

# %%
# same example can be done by 'sex(female,male)'

# %%
s = data
s[(s['sex']=='Male')|(s['sex']=='Female')]
s1 = s.groupby(['income','sex']).size()
s1.unstack(0)
# Out:
# income  <=50K  >50K
# sex
# Female   9592  1179
# Male    15128  6662

# %%
below_50 = data[data['income']=='<=50K']
below_50 = below_50.set_index('income')
below_50.head()
# Out:
#         age workclass  fnlwgt     education  education.num marital.status  \
# income
# <=50K    90         ?   77053       HS-grad              9        Widowed
# <=50K    82   Private  132870       HS-grad              9        Widowed
# <=50K    66         ?  186061  Some-college             10        Widowed
# <=50K    54   Private  140359       7th-8th              4       Divorced
# <=50K    41   Private  264663  Some-college             10      Separated
#
#                occupation   relationship   race     sex  capital.gain  \
# income
# <=50K                   ?  Not-in-family  White  Female             0
# <=50K     Exec-managerial  Not-in-family  White  Female             0
# <=50K                   ?      Unmarried  Black  Female             0
# <=50K   Machine-op-inspct      Unmarried  White  Female             0
# <=50K      Prof-specialty      Own-child  White  Female             0
#
#         capital.loss  hours.per.week native.country
# income
# ...

# %%
above_50 = data[data['income']=='>50K']
above_50 = above_50.set_index('income')
above_50.head()
# Out:
#         age         workclass  fnlwgt     education  education.num  \
# income
# >50K     74         State-gov   88638     Doctorate             16
# >50K     41           Private   70037  Some-college             10
# >50K     45           Private  172274     Doctorate             16
# >50K     38  Self-emp-not-inc  164526   Prof-school             15
# >50K     52           Private  129177     Bachelors             13
#
#        marital.status      occupation    relationship   race     sex  \
# income
# >50K    Never-married  Prof-specialty  Other-relative  White  Female
# >50K    Never-married    Craft-repair       Unmarried  White    Male
# >50K         Divorced  Prof-specialty       Unmarried  Black  Female
# >50K    Never-married  Prof-specialty   Not-in-family  White    Male
# >50K          Widowed   Other-service   Not-in-family  White  Female
#
#         capital.gain  capital.loss  hours.per.week native.country
# income
# ...

# %%
f = data[data['sex']=='Female']
f.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
m = data[data['sex']=='Male']
m.head()
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 6    38           Private  150601          10th              6      Separated
# 9    41           Private   70037  Some-college             10  Never-married
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
# 13   32           Private  136204       Masters             14      Separated
# 14   51                 ?  172175     Doctorate             16  Never-married
#
#          occupation   relationship   race   sex  capital.gain  capital.loss  \
# 6      Adm-clerical      Unmarried  White  Male             0          3770
# 9      Craft-repair      Unmarried  White  Male             0          3004
# 11   Prof-specialty  Not-in-family  White  Male             0          2824
# 13  Exec-managerial  Not-in-family  White  Male             0          2824
# 14                ?  Not-in-family  White  Male             0          2824
#
# ...

# %%
dhmap = data.corr()

# %%
sns.heatmap(dhmap,cmap='coolwarm')

# %%
above_50.pivot_table(values='age',
    index='education',
    columns='occupation')
# Out:
# occupation            ?  Adm-clerical  Armed-Forces  Craft-repair  \
# education
# 10th          64.500000           NaN           NaN     48.421053
# 11th                NaN     41.333333           NaN     39.777778
# 12th          35.500000     45.000000           NaN     41.666667
# 1st-4th             NaN           NaN           NaN     57.000000
# 5th-6th       58.500000           NaN           NaN     43.666667
# 7th-8th       61.500000     77.000000           NaN     53.125000
# 9th           63.000000     45.000000           NaN     45.000000
# Assoc-acdm    59.500000     39.000000           NaN     40.468750
# Assoc-voc     43.692308     38.222222           NaN     43.308642
# Bachelors     52.911111     42.134454           NaN     42.568182
# Doctorate     62.454545     48.500000           NaN     51.000000
# HS-grad       58.086957     44.576687           NaN     44.029630
# Masters       56.388889     47.043478          46.0     47.400000
# ...

# %%
below_50.pivot_table(values='age',
    index='education',
    columns='occupation')
# Out:
# occupation            ?  Adm-clerical  Armed-Forces  Craft-repair  \
# education
# 10th          33.040000     41.631579           NaN     39.642384
# 11th          32.252101     31.328125           NaN     33.732484
# 12th          30.736842     30.945946          34.0     37.244898
# 1st-4th       63.833333           NaN           NaN     44.428571
# 5th-6th       53.642857     40.000000           NaN     40.575000
# 7th-8th       55.492958     44.500000           NaN     44.462963
# 9th           46.880000     48.000000           NaN     39.134831
# Assoc-acdm    38.268293     36.055215           NaN     36.783133
# Assoc-voc     45.979167     36.255034           NaN     36.865497
# Bachelors     44.171875     34.428941          24.0     38.811594
# Doctorate     66.750000     31.333333           NaN     47.000000
# HS-grad       44.246407     38.102329          29.0     37.484509
# Masters       52.200000     40.955556           NaN     48.166667
# ...

# %%
data['race'].unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Other',
#        'Amer-Indian-Eskimo'], dtype=object)

# %%
data['race'].nunique()
# Out:
# 5

# %%
sns.countplot(x=data['race'],data=data,hue=data['sex'],palette='viridis')
plt.tight_layout()

# %%
oc = data.groupby('occupation').count()
oc.head()
# Out:
#                   age  workclass  fnlwgt  education  education.num  \
# occupation
# ?                1843       1843    1843       1843           1843
# Adm-clerical     3770       3770    3770       3770           3770
# Armed-Forces        9          9       9          9              9
# Craft-repair     4099       4099    4099       4099           4099
# Exec-managerial  4066       4066    4066       4066           4066
#
#                  marital.status  relationship  race   sex  capital.gain  \
# occupation
# ?                          1843          1843  1843  1843          1843
# Adm-clerical               3770          3770  3770  3770          3770
# Armed-Forces                  9             9     9     9             9
# Craft-repair               4099          4099  4099  4099          4099
# Exec-managerial            4066          4066  4066  4066          4066
#
#                  capital.loss  hours.per.week  native.country  income
# occupation
# ...

# %%
oei = data.groupby(['occupation','education']).count()['income'].unstack()
sns.heatmap(oei,cmap='coolwarm')

# %%
oei.head()
# Out:
# education         10th   11th  12th  1st-4th  5th-6th  7th-8th   9th  \
# occupation
# ?                102.0  119.0  40.0     12.0     30.0     73.0  51.0
# Adm-clerical      38.0   67.0  38.0      NaN      6.0     11.0  14.0
# Armed-Forces       NaN    NaN   1.0      NaN      NaN      NaN   NaN
# Craft-repair     170.0  175.0  58.0     23.0     43.0    116.0  96.0
# Exec-managerial   24.0   34.0  13.0      4.0      1.0     19.0  13.0
#
# education        Assoc-acdm  Assoc-voc  Bachelors  Doctorate  HS-grad  \
# occupation
# ?                      47.0       61.0      173.0       15.0    533.0
# Adm-clerical          193.0      167.0      506.0        5.0   1365.0
# Armed-Forces            NaN        NaN        1.0        NaN      4.0
# Craft-repair          115.0      252.0      226.0        2.0   1922.0
# Exec-managerial       145.0      150.0     1369.0       55.0    807.0
#
# education        Masters  Preschool  Prof-school  Some-college
# occupation
# ...

# %%
ori = data.groupby(['occupation','race']).count()['income'].unstack()
sns.heatmap(ori)

# %%
high = data[data['income']=='>50K']
high.head()
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 9    41           Private   70037  Some-college             10  Never-married
# 10   45           Private  172274     Doctorate             16       Divorced
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
# 12   52           Private  129177     Bachelors             13        Widowed
#
#         occupation    relationship   race     sex  capital.gain  capital.loss  \
# 7   Prof-specialty  Other-relative  White  Female             0          3683
# 9     Craft-repair       Unmarried  White    Male             0          3004
# 10  Prof-specialty       Unmarried  Black  Female             0          3004
# 11  Prof-specialty   Not-in-family  White    Male             0          2824
# 12   Other-service   Not-in-family  White  Female             0          2824
#
# ...

# %%
oai = high.groupby(['occupation','age']).count()['income'].unstack(0)
oai.head()
# Out:
# occupation    ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# age
# 19          1.0           NaN           NaN           NaN              NaN
# 21          NaN           1.0           NaN           NaN              NaN
# 22          NaN           NaN           NaN           1.0              1.0
# 23          NaN           2.0           NaN           2.0              NaN
# 24          1.0           2.0           NaN           3.0              5.0
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# age
# 19                      NaN                NaN                NaN
# 21                      NaN                NaN                NaN
# 22                      NaN                2.0                1.0
# 23                      NaN                NaN                1.0
# 24                      1.0                1.0                1.0
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# age
# ...

# %%
data.groupby(['occupation','workclass']).count()['income'].unstack()
# Out:
# workclass               ?  Federal-gov  Local-gov  Never-worked  Private  \
# occupation
# ?                  1836.0          NaN        NaN           7.0      NaN
# Adm-clerical          NaN        317.0      283.0           NaN   2833.0
# Armed-Forces          NaN          9.0        NaN           NaN      NaN
# Craft-repair          NaN         64.0      146.0           NaN   3195.0
# Exec-managerial       NaN        180.0      214.0           NaN   2691.0
# Farming-fishing       NaN          8.0       29.0           NaN    455.0
# Handlers-cleaners     NaN         23.0       47.0           NaN   1273.0
# Machine-op-inspct     NaN         14.0       12.0           NaN   1913.0
# Other-service         NaN         35.0      193.0           NaN   2740.0
# Priv-house-serv       NaN          NaN        NaN           NaN    149.0
# Prof-specialty        NaN        175.0      705.0           NaN   2313.0
# Protective-serv       NaN         28.0      304.0           NaN    190.0
# ...

# %%
data['net'] = data['capital.gain']-data['capital.loss']
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income   net
# 0          4356              40  United-States  <=50K -4356
# ...

# %%
gains = data[data['net']>0]
gains.head()
# Out:
#       age     workclass  fnlwgt    education  education.num  \
# 1519   54  Self-emp-inc  166459  Prof-school             15
# 1520   52       Private  152234      HS-grad              9
# 1521   53  Self-emp-inc  263925      HS-grad              9
# 1522   52       Private  118025    Bachelors             13
# 1523   46       Private  370119  Prof-school             15
#
#           marital.status       occupation relationship                race  \
# 1519  Married-civ-spouse   Prof-specialty      Husband               White
# 1520  Married-civ-spouse  Exec-managerial      Husband  Asian-Pac-Islander
# 1521  Married-civ-spouse            Sales      Husband               White
# 1522  Married-civ-spouse  Exec-managerial      Husband               White
# 1523  Married-civ-spouse   Prof-specialty      Husband               White
#
#        sex  capital.gain  capital.loss  hours.per.week native.country income  \
# ...

# %%
len(gains)
# Out:
# 2712

# %%
loses = data[data['net']<=0]
len(loses)
# Out:
# 29849

# %%
#It seems generally approximately age people make much money is 45 years old and above.
#That migt cause accumulated income of people.
dv = data.pivot_table(index='education',columns='income',values='age')
sns.heatmap(dv,cmap='coolwarm',linecolor='white',linewidths=1)

# %%
co = data['native.country'].value_counts()
co = co.head(10)
co
# Out:
# United-States    29170
# Mexico             643
# ?                  583
# Philippines        198
# Germany            137
# Canada             121
# Puerto-Rico        114
# El-Salvador        106
# India              100
# Cuba                95
# Name: native.country, dtype: int64

# %%
data['income'] = data['income'].map({'<=50K':0,'>50K':1})

# %%
sns.barplot(x='workclass',y='income',data=data)
sns.set_context('poster')

# %%
sns.boxplot(x='income',y='education.num',data=data,hue='sex')
